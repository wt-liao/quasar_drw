# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import h5py
from astropy.io import fits

# %% [markdown]
# ## read-in selected quasars

# %%
quasar_select = np.loadtxt("quasar_select.txt")

# %%
ra_select  = quasar_select[0, :]
dec_select = quasar_select[1, :]
z_select   = quasar_select[2, :]

# %%
flag_select = np.ones( len(ra_select), dtype=object )

# %% [markdown]
# ## read-in catalog data

# %%
fits_file = fits.open("final_SN_field_qso&candidate.fits")

# %%
fits_file.info()
# Out:
# Filename: final_SN_field_qso&candidate.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU     18   3687R x 5C   [E, E, E, E, 2A]

# %%
catalog = fits_file[1]

# %% [raw]
# catalog.header

# %% [raw]
# catalog.data

# %%
ra   = catalog.data["RA"]
dec  = catalog.data["DEC"]
z    = catalog.data["Redshift"]
flag = catalog.data["Type"]

# %%
len(dec)
# Out:
# 3687

# %% [markdown]
# ## Match

# %%
for i in range(len(ra_select)):
    ra_curr  = ra_select[i]
    dec_curr = dec_select[i]
    z_curr   = z_select[i]
    
    match = False
    dist_best = 1000.0
    
    for j in range(len(ra)):
        dist = (ra_curr-ra[j])**2.0 + (dec_curr-dec[j])**2.0
        dist = np.sqrt(dist)
        
        if (dist < 6.0e-4) and (dist < dist_best):
            match = True
            dist_best = dist
            flag_select[i] = flag[j]
            
            print(f"For {i:2d} quasar: flag = {flag[j]:4s}")
            
    if not match:
        print("Fail to match !!!!!!!")
# Out:
# For  0 quasar: flag = Q
# For  1 quasar: flag = Q
# For  2 quasar: flag = q
# For  3 quasar: flag = q
# For  4 quasar: flag = qQ
# For  5 quasar: flag = Q
# For  6 quasar: flag = qQ
# For  7 quasar: flag = q
# For  8 quasar: flag = qQ
# For  9 quasar: flag = QQ
# For 10 quasar: flag = q
# For 11 quasar: flag = qQ
# For 12 quasar: flag = Q
# For 13 quasar: flag = Q
# For 14 quasar: flag = qQ
# For 15 quasar: flag = q
# For 16 quasar: flag = qQ
# For 17 quasar: flag = q
# For 18 quasar: flag = qQ
# For 19 quasar: flag = QQ
# For 20 quasar: flag = Q
# For 21 quasar: flag = Q
# For 22 quasar: flag = q
# For 23 quasar: flag = qQ
# For 24 quasar: flag = Q
# For 25 quasar: flag = qQ
# For 26 quasar: flag = Q
# For 27 quasar: flag = Q
# For 28 quasar: flag = q
# For 29 quasar: flag = QQ
# For 30 quasar: flag = qQ
# For 31 quasar: flag = QQ
# For 32 quasar: flag = qQ
# For 33 quasar: flag = Q
# For 34 quasar: flag = QQ
# For 35 quasar: flag = QQ
# For 36 quasar: flag = Q
# For 37 quasar: flag = Q
# For 38 quasar: flag = QQ
# For 39 quasar: flag = QQ
# For 40 quasar: flag = Q
# For 41 quasar: flag = qQ
# For 42 quasar: flag = QQ
# For 43 quasar: flag = Q
# For 44 quasar: flag = Q
# For 45 quasar: flag = QQ
# For 46 quasar: flag = Q
# For 47 quasar: flag = Q
# For 48 quasar: flag = q
# For 49 quasar: flag = QQ
# For 50 quasar: flag = qQ
# For 51 quasar: flag = Q
# For 52 quasar: flag = QQ
# For 53 quasar: flag = QQ
# For 54 quasar: flag = qQ
# For 55 quasar: flag = qQ
# For 56 quasar: flag = q
# For 57 quasar: flag = QQ
# For 58 quasar: flag = Q
# For 59 quasar: flag = qQ
# For 60 quasar: flag = Q
# For 61 quasar: flag = Q
# For 62 quasar: flag = qQ
# For 63 quasar: flag = qQ
# For 64 quasar: flag = Q
# For 65 quasar: flag = qQ
# For 66 quasar: flag = Q
# For 67 quasar: flag = qQ
# For 68 quasar: flag = QQ
# For 69 quasar: flag = Q
# For 70 quasar: flag = Q
# For 71 quasar: flag = q
# For 72 quasar: flag = QQ
# For 73 quasar: flag = Q
# For 74 quasar: flag = qQ
# For 75 quasar: flag = Q
# For 76 quasar: flag = qQ
# For 77 quasar: flag = q
# For 78 quasar: flag = qQ
# For 79 quasar: flag = Q
# For 80 quasar: flag = qQ
# For 81 quasar: flag = QQ
# For 82 quasar: flag = Q
# For 83 quasar: flag = qQ
# For 84 quasar: flag = qQ
# For 85 quasar: flag = Q
# For 86 quasar: flag = qQ
# For 87 quasar: flag = QQ
# For 88 quasar: flag = Q
# For 89 quasar: flag = qQ
# For 90 quasar: flag = Q
# For 91 quasar: flag = Q
# For 92 quasar: flag = Q
# For 93 quasar: flag = Q
# For 94 quasar: flag = Q
# For 95 quasar: flag = QQ
# For 96 quasar: flag = qQ
# For 97 quasar: flag = Q
# For 98 quasar: flag = Q
# For 99 quasar: flag = QQ
# For 100 quasar: flag = Q
# For 101 quasar: flag = qQ
# For 102 quasar: flag = Q
# For 103 quasar: flag = Q
# For 104 quasar: flag = q
# For 105 quasar: flag = QQ
# For 106 quasar: flag = Q
# For 107 quasar: flag = qQ
# For 108 quasar: flag = q
# For 109 quasar: flag = Q
# For 110 quasar: flag = q
# For 111 quasar: flag = Q
# For 112 quasar: flag = qQ
# For 113 quasar: flag = Q
# For 114 quasar: flag = QQ
# For 115 quasar: flag = qQ
# For 116 quasar: flag = QQ
# For 117 quasar: flag = qQ
# For 118 quasar: flag = q
# For 119 quasar: flag = Q
# For 120 quasar: flag = qQ
# For 121 quasar: flag = qQ
# For 122 quasar: flag = Q
# For 123 quasar: flag = qQ
# For 124 quasar: flag = Q
# For 125 quasar: flag = qQ
# For 126 quasar: flag = qQ
# For 127 quasar: flag = QQ
# For 128 quasar: flag = Q
# For 129 quasar: flag = Q
# For 130 quasar: flag = qQ
# For 131 quasar: flag = QQ
# For 132 quasar: flag = Q
# For 133 quasar: flag = qQ
# For 134 quasar: flag = qQ
# For 135 quasar: flag = Q
# For 136 quasar: flag = Q
# For 137 quasar: flag = qQ
# For 138 quasar: flag = QQ
# For 139 quasar: flag = qQ
# For 140 quasar: flag = Q
# For 141 quasar: flag = qQ
# For 142 quasar: flag = Q
# For 143 quasar: flag = q
# For 144 quasar: flag = q
# For 145 quasar: flag = qQ
# For 146 quasar: flag = Q
# For 147 quasar: flag = QQ
# For 148 quasar: flag = QQ
# For 149 quasar: flag = Q
# For 150 quasar: flag = Q
# For 151 quasar: flag = qQ
# For 152 quasar: flag = Q
# For 153 quasar: flag = qQ
# For 154 quasar: flag = q
# For 155 quasar: flag = q
# For 156 quasar: flag = Q
# For 157 quasar: flag = qQ
# For 158 quasar: flag = Q
# For 159 quasar: flag = Q
# For 160 quasar: flag = Q
# For 161 quasar: flag = Q
# For 162 quasar: flag = qQ
# For 163 quasar: flag = Q
# For 164 quasar: flag = Q
# For 165 quasar: flag = Q
# For 166 quasar: flag = qQ
# For 167 quasar: flag = qQ
# For 168 quasar: flag = Q
# For 169 quasar: flag = QQ
# For 170 quasar: flag = qQ
# For 171 quasar: flag = QQ
# For 172 quasar: flag = q
# For 173 quasar: flag = Q
# For 174 quasar: flag = Q
# For 175 quasar: flag = q
# For 176 quasar: flag = Q
# For 177 quasar: flag = Q
# For 178 quasar: flag = qQ
# For 179 quasar: flag = qQ
# For 180 quasar: flag = Q
# For 181 quasar: flag = QQ
# For 182 quasar: flag = q
# For 183 quasar: flag = QQ
# For 184 quasar: flag = qQ
# For 185 quasar: flag = QQ
# For 186 quasar: flag = qQ
# For 187 quasar: flag = QQ
# For 188 quasar: flag = Q
# For 189 quasar: flag = Q
# For 190 quasar: flag = Q
# For 191 quasar: flag = Q
# For 192 quasar: flag = qQ
# For 193 quasar: flag = qQ
# For 194 quasar: flag = qQ
# For 195 quasar: flag = Q
# For 196 quasar: flag = q
# For 197 quasar: flag = QQ
# For 198 quasar: flag = qQ
# For 199 quasar: flag = Q
# For 200 quasar: flag = q
# For 201 quasar: flag = QQ
# For 202 quasar: flag = QQ
# For 203 quasar: flag = qQ
# For 204 quasar: flag = Q
# For 205 quasar: flag = QQ
# For 206 quasar: flag = QQ
# For 207 quasar: flag = q
# For 208 quasar: flag = QQ
# For 209 quasar: flag = QQ
# For 210 quasar: flag = QQ
# For 211 quasar: flag = qQ
# For 212 quasar: flag = q
# For 213 quasar: flag = Q
# For 214 quasar: flag = Q
# For 215 quasar: flag = qQ
# For 216 quasar: flag = QQ
# For 217 quasar: flag = Q
# For 218 quasar: flag = Q
# For 219 quasar: flag = qQ
# For 220 quasar: flag = Q
# For 221 quasar: flag = QQ
# For 222 quasar: flag = Q
# For 223 quasar: flag = Q
# For 224 quasar: flag = Q
# For 225 quasar: flag = qQ
# For 226 quasar: flag = q
# For 227 quasar: flag = QQ
# For 228 quasar: flag = qQ
# For 229 quasar: flag = Q
# For 230 quasar: flag = q
# For 231 quasar: flag = q
# For 232 quasar: flag = Q
# For 233 quasar: flag = Q
# For 234 quasar: flag = QQ
# For 235 quasar: flag = Q
# For 236 quasar: flag = Q
# For 237 quasar: flag = QQ
# For 238 quasar: flag = qQ
# For 239 quasar: flag = Q
# For 240 quasar: flag = QQ
# For 241 quasar: flag = Q
# For 242 quasar: flag = q
# For 243 quasar: flag = Q
# For 244 quasar: flag = Q
# For 245 quasar: flag = Q
# For 246 quasar: flag = Q
# For 247 quasar: flag = Q
# For 248 quasar: flag = Q
# For 249 quasar: flag = Q
# For 250 quasar: flag = Q
# For 251 quasar: flag = Q
# For 252 quasar: flag = qQ
# For 253 quasar: flag = Q
# For 254 quasar: flag = Q
# For 255 quasar: flag = Q
# For 256 quasar: flag = qQ
# For 257 quasar: flag = Q
# For 258 quasar: flag = Q
# For 259 quasar: flag = Q
# For 260 quasar: flag = QQ
# For 261 quasar: flag = Q
# For 262 quasar: flag = q
# For 263 quasar: flag = qQ
# For 264 quasar: flag = Q
# For 265 quasar: flag = Q
# For 266 quasar: flag = Q
# For 267 quasar: flag = Q
# For 268 quasar: flag = Q
# For 269 quasar: flag = q
# For 270 quasar: flag = q
# For 271 quasar: flag = Q
# For 272 quasar: flag = Q
# For 273 quasar: flag = qQ
# For 274 quasar: flag = Q
# For 275 quasar: flag = QQ
# For 276 quasar: flag = q
# For 277 quasar: flag = Q
# For 278 quasar: flag = Q
# For 279 quasar: flag = Q
# For 280 quasar: flag = QQ
# For 281 quasar: flag = Q
# For 282 quasar: flag = Q
# For 283 quasar: flag = Q
# For 284 quasar: flag = q
# For 285 quasar: flag = QQ
# For 286 quasar: flag = Q
# For 287 quasar: flag = q
# For 288 quasar: flag = Q
# For 289 quasar: flag = Q
# For 290 quasar: flag = Q
# For 291 quasar: flag = Q
# For 292 quasar: flag = Q
# For 293 quasar: flag = QQ
# For 294 quasar: flag = qQ
# For 295 quasar: flag = Q
# For 296 quasar: flag = q
# For 297 quasar: flag = Q
# For 298 quasar: flag = Q
# For 299 quasar: flag = Q
# For 300 quasar: flag = QQ
# For 301 quasar: flag = qQ
# For 302 quasar: flag = Q
# For 303 quasar: flag = Q
# For 304 quasar: flag = Q
# For 305 quasar: flag = Q
# For 306 quasar: flag = q
# For 307 quasar: flag = QQ
# For 308 quasar: flag = Q
# For 309 quasar: flag = qQ
# For 310 quasar: flag = QQ
# For 311 quasar: flag = QQ
# For 312 quasar: flag = qQ
# For 313 quasar: flag = qQ
# For 314 quasar: flag = Q
# For 315 quasar: flag = qQ
# For 316 quasar: flag = Q
# For 317 quasar: flag = Q
# For 318 quasar: flag = QQ
# For 319 quasar: flag = Q
# For 320 quasar: flag = qQ
# For 321 quasar: flag = Q
# For 322 quasar: flag = QQ
# For 323 quasar: flag = qQ
# For 324 quasar: flag = Q
# For 325 quasar: flag = QQ
# For 326 quasar: flag = Q
# For 327 quasar: flag = Q
# For 328 quasar: flag = Q
# For 329 quasar: flag = Q
# For 330 quasar: flag = Q
# For 331 quasar: flag = Q
# For 332 quasar: flag = qQ
# For 333 quasar: flag = QQ
# For 334 quasar: flag = q
# For 335 quasar: flag = Q
# For 336 quasar: flag = QQ
# For 337 quasar: flag = QQ
# For 338 quasar: flag = QQ
# For 339 quasar: flag = qQ
# For 340 quasar: flag = Q
# For 341 quasar: flag = q
# For 342 quasar: flag = Q
# For 343 quasar: flag = Q
# For 344 quasar: flag = qQ
# For 345 quasar: flag = QQ
# For 346 quasar: flag = qQ
# For 347 quasar: flag = Q
# For 348 quasar: flag = Q
# For 349 quasar: flag = q
# For 350 quasar: flag = QQ
# For 351 quasar: flag = qQ
# For 352 quasar: flag = q
# For 353 quasar: flag = Q
# For 354 quasar: flag = qQ
# For 355 quasar: flag = Q
# For 356 quasar: flag = qQ
# For 357 quasar: flag = Q
# For 358 quasar: flag = Q
# For 359 quasar: flag = QQ
# For 360 quasar: flag = qQ
# For 361 quasar: flag = QQ
# For 362 quasar: flag = qQ
# For 363 quasar: flag = qQ
# For 364 quasar: flag = Q
# For 365 quasar: flag = Q
# For 366 quasar: flag = QQ
# For 367 quasar: flag = Q
# For 368 quasar: flag = QQ
# For 369 quasar: flag = q
# For 370 quasar: flag = q
# For 371 quasar: flag = q
# For 372 quasar: flag = qQ
# For 373 quasar: flag = q
# For 374 quasar: flag = qQ
# For 375 quasar: flag = QQ
# For 376 quasar: flag = Q
# For 377 quasar: flag = QQ
# For 378 quasar: flag = qQ
# For 379 quasar: flag = QQ
# For 380 quasar: flag = Q
# For 381 quasar: flag = Q
# For 382 quasar: flag = q
# For 383 quasar: flag = Q
# For 384 quasar: flag = Q
# For 385 quasar: flag = Q
# For 386 quasar: flag = Q
# For 387 quasar: flag = qQ
# For 388 quasar: flag = Q
# For 389 quasar: flag = Q
# For 390 quasar: flag = qQ
# For 391 quasar: flag = Q
# For 392 quasar: flag = QQ
# For 393 quasar: flag = QQ
# For 394 quasar: flag = Q
# For 395 quasar: flag = Q
# For 396 quasar: flag = qQ
# For 397 quasar: flag = q
# For 398 quasar: flag = qQ
# For 399 quasar: flag = QQ
# For 400 quasar: flag = Q
# For 401 quasar: flag = Q
# For 402 quasar: flag = Q
# For 403 quasar: flag = Q
# For 404 quasar: flag = QQ
# For 405 quasar: flag = Q
# For 406 quasar: flag = qQ
# For 407 quasar: flag = QQ
# For 408 quasar: flag = Q
# For 409 quasar: flag = qQ
# For 410 quasar: flag = Q
# For 411 quasar: flag = q
# For 412 quasar: flag = QQ
# For 413 quasar: flag = Q
# For 414 quasar: flag = q
# For 415 quasar: flag = Q
# For 416 quasar: flag = qQ
# For 417 quasar: flag = q
# For 418 quasar: flag = Q
# For 419 quasar: flag = Q
# For 420 quasar: flag = qQ
# For 421 quasar: flag = QQ
# For 422 quasar: flag = q
# For 423 quasar: flag = Q
# For 424 quasar: flag = Q
# For 425 quasar: flag = q
# For 426 quasar: flag = Q
# For 427 quasar: flag = QQ
# For 428 quasar: flag = qQ
# For 429 quasar: flag = QQ
# For 430 quasar: flag = Q
# For 431 quasar: flag = Q
# For 432 quasar: flag = Q
# For 433 quasar: flag = QQ
# For 434 quasar: flag = QQ
# For 435 quasar: flag = Q
# For 436 quasar: flag = qQ
# For 437 quasar: flag = qQ
# For 438 quasar: flag = QQ
# For 439 quasar: flag = q
# For 440 quasar: flag = Q
# For 441 quasar: flag = Q
# For 442 quasar: flag = qQ
# For 443 quasar: flag = q
# For 444 quasar: flag = Q
# For 445 quasar: flag = Q
# For 446 quasar: flag = Q
# For 447 quasar: flag = q
# For 448 quasar: flag = Q
# For 449 quasar: flag = q
# For 450 quasar: flag = q
# For 451 quasar: flag = Q
# For 452 quasar: flag = Q
# For 453 quasar: flag = QQ
# For 454 quasar: flag = Q
# For 455 quasar: flag = QQ
# For 456 quasar: flag = Q
# For 457 quasar: flag = QQ
# For 458 quasar: flag = Q
# For 459 quasar: flag = Q
# For 460 quasar: flag = Q
# For 461 quasar: flag = qQ
# For 462 quasar: flag = Q
# For 463 quasar: flag = q
# For 464 quasar: flag = q
# For 465 quasar: flag = q
# For 466 quasar: flag = q
# For 467 quasar: flag = q
# For 468 quasar: flag = q
# For 469 quasar: flag = Q
# For 470 quasar: flag = Q
# For 471 quasar: flag = qQ
# For 472 quasar: flag = QQ
# For 473 quasar: flag = Q
# For 474 quasar: flag = qQ
# For 475 quasar: flag = q
# For 476 quasar: flag = qQ
# For 477 quasar: flag = QQ
# For 478 quasar: flag = qQ
# For 479 quasar: flag = Q
# For 480 quasar: flag = QQ
# For 481 quasar: flag = qQ
# For 482 quasar: flag = Q
# For 483 quasar: flag = qQ
# For 484 quasar: flag = q
# For 485 quasar: flag = q
# For 486 quasar: flag = qQ
# For 487 quasar: flag = QQ
# For 488 quasar: flag = Q
# For 489 quasar: flag = qQ
# For 490 quasar: flag = Q
# For 491 quasar: flag = QQ
# For 492 quasar: flag = QQ
# For 493 quasar: flag = QQ
# For 494 quasar: flag = QQ
# For 495 quasar: flag = q
# For 496 quasar: flag = qQ
# For 497 quasar: flag = Q
# For 498 quasar: flag = qQ
# For 499 quasar: flag = qQ
# For 500 quasar: flag = q
# For 501 quasar: flag = Q
# For 502 quasar: flag = Q
# For 503 quasar: flag = qQ
# For 504 quasar: flag = q
# For 505 quasar: flag = Q
# For 506 quasar: flag = q
# For 507 quasar: flag = q
# For 508 quasar: flag = Q
# For 509 quasar: flag = qQ
# For 510 quasar: flag = QQ
# For 511 quasar: flag = QQ
# For 512 quasar: flag = Q
# For 513 quasar: flag = qQ
# For 514 quasar: flag = QQ
# For 515 quasar: flag = Q
# For 516 quasar: flag = Q
# For 517 quasar: flag = qQ
# For 518 quasar: flag = QQ
# For 519 quasar: flag = qQ
# For 520 quasar: flag = Q
# For 521 quasar: flag = qQ
# For 522 quasar: flag = Q
# For 523 quasar: flag = qQ
# For 524 quasar: flag = QQ
# For 525 quasar: flag = Q
# For 526 quasar: flag = Q
# For 527 quasar: flag = QQ
# For 528 quasar: flag = Q
# For 529 quasar: flag = q
# For 530 quasar: flag = Q
# For 531 quasar: flag = QQ
# For 532 quasar: flag = QQ
# For 533 quasar: flag = q
# For 534 quasar: flag = qQ
# For 535 quasar: flag = qQ
# For 536 quasar: flag = q
# For 537 quasar: flag = QQ
# For 538 quasar: flag = Q
# For 539 quasar: flag = Q
# For 540 quasar: flag = q
# For 541 quasar: flag = QQ
# For 542 quasar: flag = Q
# For 543 quasar: flag = qQ
# For 544 quasar: flag = qQ
# For 545 quasar: flag = QQ
# For 546 quasar: flag = qQ
# For 547 quasar: flag = q
# For 548 quasar: flag = QQ
# For 549 quasar: flag = Q
# For 550 quasar: flag = qQ
# For 551 quasar: flag = q
# For 552 quasar: flag = Q
# For 553 quasar: flag = qQ
# For 554 quasar: flag = qQ
# For 555 quasar: flag = Q
# For 556 quasar: flag = QQ
# For 557 quasar: flag = Q
# For 558 quasar: flag = QQ
# For 559 quasar: flag = q
# For 560 quasar: flag = q
# For 561 quasar: flag = q
# For 562 quasar: flag = QQ
# For 563 quasar: flag = Q
# For 564 quasar: flag = Q
# For 565 quasar: flag = q
# For 566 quasar: flag = q
# For 567 quasar: flag = qQ
# For 568 quasar: flag = Q
# For 569 quasar: flag = qQ
# For 570 quasar: flag = qQ
# For 571 quasar: flag = QQ
# For 572 quasar: flag = q
# For 573 quasar: flag = qQ
# For 574 quasar: flag = Q
# For 575 quasar: flag = qQ
# For 576 quasar: flag = q
# For 577 quasar: flag = q
# For 578 quasar: flag = Q
# For 579 quasar: flag = QQ
# For 580 quasar: flag = Q
# For 581 quasar: flag = Q
# For 582 quasar: flag = Q
# For 583 quasar: flag = Q
# For 584 quasar: flag = qQ
# For 585 quasar: flag = qQ
# For 586 quasar: flag = qQ
# For 587 quasar: flag = Q
# For 588 quasar: flag = q
# For 589 quasar: flag = Q
# For 590 quasar: flag = Q
# For 591 quasar: flag = q
# For 592 quasar: flag = qQ
# For 593 quasar: flag = Q
# For 594 quasar: flag = Q
# For 595 quasar: flag = Q
# For 596 quasar: flag = qQ
# For 597 quasar: flag = QQ
# For 598 quasar: flag = q
# For 599 quasar: flag = QQ
# For 600 quasar: flag = qQ
# For 601 quasar: flag = Q
# For 602 quasar: flag = QQ
# For 603 quasar: flag = Q
# For 604 quasar: flag = Q
# For 605 quasar: flag = Q
# For 606 quasar: flag = QQ
# For 607 quasar: flag = qQ
# For 608 quasar: flag = qQ
# For 609 quasar: flag = q
# For 610 quasar: flag = Q
# For 611 quasar: flag = Q
# For 612 quasar: flag = Q
# For 613 quasar: flag = Q
# For 614 quasar: flag = qQ
# For 615 quasar: flag = QQ
# For 616 quasar: flag = q
# For 617 quasar: flag = q
# For 618 quasar: flag = Q
# For 619 quasar: flag = QQ
# For 620 quasar: flag = Q
# For 621 quasar: flag = q
# For 622 quasar: flag = Q
# For 623 quasar: flag = QQ
# For 624 quasar: flag = QQ
# For 625 quasar: flag = qQ
# For 626 quasar: flag = Q
# For 627 quasar: flag = q
# For 628 quasar: flag = QQ
# For 629 quasar: flag = Q
# For 630 quasar: flag = Q
# For 631 quasar: flag = qQ
# For 632 quasar: flag = q
# For 633 quasar: flag = Q
# For 634 quasar: flag = Q
# For 635 quasar: flag = Q
# For 636 quasar: flag = QQ
# For 637 quasar: flag = q
# For 638 quasar: flag = QQ
# For 639 quasar: flag = qQ
# For 640 quasar: flag = Q
# For 641 quasar: flag = q
# For 642 quasar: flag = qQ
# For 643 quasar: flag = Q
# For 644 quasar: flag = q
# For 645 quasar: flag = q
# For 646 quasar: flag = q
# For 647 quasar: flag = qQ
# For 648 quasar: flag = q
# For 649 quasar: flag = QQ
# For 650 quasar: flag = QQ
# For 651 quasar: flag = q
# For 652 quasar: flag = QQ
# For 653 quasar: flag = Q
# For 654 quasar: flag = QQ
# For 655 quasar: flag = q
# For 656 quasar: flag = Q
# For 657 quasar: flag = QQ
# For 658 quasar: flag = Q
# For 659 quasar: flag = Q
# For 660 quasar: flag = Q
# For 661 quasar: flag = qQ
# For 662 quasar: flag = Q
# For 663 quasar: flag = q
# For 664 quasar: flag = q
# For 665 quasar: flag = Q
# For 666 quasar: flag = Q
# For 667 quasar: flag = Q
# For 668 quasar: flag = Q
# For 669 quasar: flag = Q
# For 670 quasar: flag = q
# For 671 quasar: flag = q
# For 672 quasar: flag = q
# For 673 quasar: flag = Q
# For 674 quasar: flag = QQ
# For 675 quasar: flag = QQ
# For 676 quasar: flag = QQ
# For 677 quasar: flag = q
# For 678 quasar: flag = Q
# For 679 quasar: flag = Q
# For 680 quasar: flag = q
# For 681 quasar: flag = q
# For 682 quasar: flag = Q
# For 683 quasar: flag = Q
# For 684 quasar: flag = Q
# For 685 quasar: flag = q
# For 686 quasar: flag = Q
# For 687 quasar: flag = Q
# For 688 quasar: flag = q
# For 689 quasar: flag = Q
# For 690 quasar: flag = QQ
# For 691 quasar: flag = qQ
# For 692 quasar: flag = q
# For 693 quasar: flag = Q
# For 694 quasar: flag = Q
# For 695 quasar: flag = QQ
# For 696 quasar: flag = qQ
# For 697 quasar: flag = QQ
# For 698 quasar: flag = QQ
# For 699 quasar: flag = Q
# For 700 quasar: flag = Q
# For 701 quasar: flag = Q
# For 702 quasar: flag = qQ
# For 703 quasar: flag = QQ
# For 704 quasar: flag = Q
# For 705 quasar: flag = qQ
# For 706 quasar: flag = Q
# For 707 quasar: flag = QQ
# For 708 quasar: flag = Q
# For 709 quasar: flag = Q
# For 710 quasar: flag = QQ
# For 711 quasar: flag = Q
# For 712 quasar: flag = Q
# For 713 quasar: flag = qQ
# For 714 quasar: flag = q
# For 715 quasar: flag = q
# For 716 quasar: flag = qQ
# For 717 quasar: flag = q
# For 718 quasar: flag = QQ
# For 719 quasar: flag = qQ
# For 720 quasar: flag = Q
# For 721 quasar: flag = Q
# For 722 quasar: flag = q
# For 723 quasar: flag = QQ
# For 724 quasar: flag = qQ
# For 725 quasar: flag = Q
# For 726 quasar: flag = Q
# For 727 quasar: flag = q
# For 728 quasar: flag = q
# For 729 quasar: flag = QQ
# For 730 quasar: flag = qQ
# For 731 quasar: flag = Q
# For 732 quasar: flag = qQ
# For 733 quasar: flag = q
# For 734 quasar: flag = Q
# For 735 quasar: flag = QQ
# For 736 quasar: flag = Q
# For 737 quasar: flag = Q
# For 738 quasar: flag = Q
# For 739 quasar: flag = q
# For 740 quasar: flag = QQ
# For 741 quasar: flag = Q
# For 742 quasar: flag = Q
# For 743 quasar: flag = q
# For 744 quasar: flag = QQ
# For 745 quasar: flag = qQ
# For 746 quasar: flag = q
# For 747 quasar: flag = q
# For 748 quasar: flag = QQ
# For 749 quasar: flag = qQ
# For 750 quasar: flag = q
# For 751 quasar: flag = QQ
# For 752 quasar: flag = qQ
# For 753 quasar: flag = Q
# For 754 quasar: flag = QQ
# For 755 quasar: flag = QQ
# For 756 quasar: flag = qQ
# For 757 quasar: flag = QQ
# For 758 quasar: flag = q
# For 759 quasar: flag = qQ
# For 760 quasar: flag = q
# For 761 quasar: flag = QQ
# For 762 quasar: flag = Q
# For 763 quasar: flag = Q
# For 764 quasar: flag = qQ
# For 765 quasar: flag = q
# For 766 quasar: flag = Q
# For 767 quasar: flag = q
# For 768 quasar: flag = Q
# For 769 quasar: flag = q
# For 770 quasar: flag = Q
# For 771 quasar: flag = qQ
# For 772 quasar: flag = qQ
# For 773 quasar: flag = qQ
# For 774 quasar: flag = Q
# For 775 quasar: flag = Q
# For 776 quasar: flag = Q
# For 777 quasar: flag = QQ
# For 778 quasar: flag = qQ
# For 779 quasar: flag = qQ
# For 780 quasar: flag = Q
# For 781 quasar: flag = QQ
# For 782 quasar: flag = qQ
# For 783 quasar: flag = QQ
# For 784 quasar: flag = q
# For 785 quasar: flag = q
# For 786 quasar: flag = QQ
# For 787 quasar: flag = qQ
# For 788 quasar: flag = Q
# For 789 quasar: flag = qQ
# For 790 quasar: flag = qQ
# For 791 quasar: flag = q
# For 792 quasar: flag = qQ
# For 793 quasar: flag = qQ
# For 794 quasar: flag = Q
# For 795 quasar: flag = Q
# For 796 quasar: flag = qQ
# For 797 quasar: flag = Q
# For 798 quasar: flag = qQ
# For 799 quasar: flag = qQ
# For 800 quasar: flag = q
# For 801 quasar: flag = QQ
# For 802 quasar: flag = qQ
# For 803 quasar: flag = Q
# For 804 quasar: flag = qQ
# For 805 quasar: flag = QQ
# For 806 quasar: flag = q
# For 807 quasar: flag = qQ
# For 808 quasar: flag = qQ
# For 809 quasar: flag = QQ
# For 810 quasar: flag = q
# For 811 quasar: flag = qQ
# For 812 quasar: flag = qQ
# For 813 quasar: flag = qQ
# For 814 quasar: flag = q
# For 815 quasar: flag = q
# For 816 quasar: flag = Q
# For 817 quasar: flag = QQ
# For 818 quasar: flag = Q
# For 819 quasar: flag = QQ
# For 820 quasar: flag = Q
# For 821 quasar: flag = qQ
# For 822 quasar: flag = q
# For 823 quasar: flag = qQ
# For 824 quasar: flag = q
# For 825 quasar: flag = Q
# For 826 quasar: flag = QQ
# For 827 quasar: flag = q
# For 828 quasar: flag = qQ
# For 829 quasar: flag = Q
# For 830 quasar: flag = QQ
# For 831 quasar: flag = QQ
# For 832 quasar: flag = QQ
# For 833 quasar: flag = Q
# For 834 quasar: flag = Q
# For 835 quasar: flag = QQ
# For 836 quasar: flag = q
# For 837 quasar: flag = Q
# For 838 quasar: flag = Q
# For 839 quasar: flag = Q
# For 840 quasar: flag = QQ
# For 841 quasar: flag = QQ
# For 842 quasar: flag = qQ
# For 843 quasar: flag = Q
# For 844 quasar: flag = q
# For 845 quasar: flag = Q
# For 846 quasar: flag = q
# For 847 quasar: flag = QQ
# For 848 quasar: flag = q
# For 849 quasar: flag = q
# For 850 quasar: flag = q
# For 851 quasar: flag = q
# For 852 quasar: flag = QQ
# For 853 quasar: flag = Q
# For 854 quasar: flag = Q
# For 855 quasar: flag = QQ
# For 856 quasar: flag = q
# For 857 quasar: flag = qQ
# For 858 quasar: flag = q
# For 859 quasar: flag = Q
# For 860 quasar: flag = q
# For 861 quasar: flag = q
# For 862 quasar: flag = qQ
# For 863 quasar: flag = q
# For 864 quasar: flag = q
# For 865 quasar: flag = Q
# For 866 quasar: flag = q
# For 867 quasar: flag = QQ
# For 868 quasar: flag = q
# For 869 quasar: flag = QQ
# For 870 quasar: flag = Q
# For 871 quasar: flag = Q
# For 872 quasar: flag = q
# For 873 quasar: flag = qQ
# For 874 quasar: flag = q
# For 875 quasar: flag = Q
# For 876 quasar: flag = qQ
# For 877 quasar: flag = q
# For 878 quasar: flag = q
# For 879 quasar: flag = q
# For 880 quasar: flag = qQ
# For 881 quasar: flag = QQ
# For 882 quasar: flag = qQ
# For 883 quasar: flag = q
# For 884 quasar: flag = QQ
# For 885 quasar: flag = q
# For 886 quasar: flag = q
# For 887 quasar: flag = Q
# For 888 quasar: flag = qQ
# For 889 quasar: flag = Q
# For 890 quasar: flag = q
# For 891 quasar: flag = q
# For 892 quasar: flag = Q
# For 893 quasar: flag = q
# For 894 quasar: flag = q
# For 895 quasar: flag = Q
# For 896 quasar: flag = QQ
# For 897 quasar: flag = QQ
# For 898 quasar: flag = Q
# For 899 quasar: flag = Q
# For 900 quasar: flag = Q
# For 901 quasar: flag = qQ
# For 902 quasar: flag = qQ
# For 903 quasar: flag = Q
# For 904 quasar: flag = QQ
# For 905 quasar: flag = Q
# For 906 quasar: flag = q
# For 907 quasar: flag = Q
# For 908 quasar: flag = qQ
# For 909 quasar: flag = qQ
# For 910 quasar: flag = q
# For 911 quasar: flag = Q
# For 912 quasar: flag = q
# For 913 quasar: flag = qQ
# For 914 quasar: flag = qQ
# For 915 quasar: flag = QQ
# For 916 quasar: flag = QQ
# For 917 quasar: flag = Q
# For 918 quasar: flag = q
# For 919 quasar: flag = Q
# For 920 quasar: flag = Q

# %%
S82_count   = 0
ozDES_count = 0

for i in range(len(flag_select)):
    if flag_select[i] == "QQ":
        ozDES_count += 1
    elif flag_select[i] == "Q":
        S82_count += 1

# %%
print(ozDES_count)
# Out:
# 179

# %%
print(S82_count)
# Out:
# 362
